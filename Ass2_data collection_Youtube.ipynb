# %%
import googleapiclient.discovery
import pandas as pd
import json
from googleapiclient.errors import HttpError  # Import HttpError to handle HTTP exceptions

# Define your API key
API_KEY = 'AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM'  
# API_KEY = 'AIzaSyCsIWUkBsJSaKg9ziO5H-Hs78MwHIK8LLM'

# Create a YouTube API client
youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=API_KEY)

def get_video_details_by_hashtag(hashtag, max_results=50):
    """
    Get details of videos matching the hashtag. Default max_results is set to 50 (maximum allowed).
    This function also handles pagination to retrieve all videos matching the hashtag.
    """
    videos = []
    next_page_token = None

    while True:
        # Request to search videos using the hashtag
        request = youtube.search().list(
            q=hashtag,  # Use the hashtag as the search query
            part="snippet",
            type="video",
            maxResults=max_results,  # Set maxResults to the maximum (50)
            pageToken=next_page_token  # Handle pagination with nextPageToken
        )
        response = request.execute()
        
        for item in response.get("items", []):
            video_data = {
                "video_id": item["id"]["videoId"],
                "author": item["snippet"]["channelTitle"],
                "title": item["snippet"]["title"],
                "description": item["snippet"]["description"],
                "publish_time": item["snippet"]["publishedAt"]
            }
            videos.append(video_data)

        # Check if there is another page of results
        next_page_token = response.get("nextPageToken")
        if not next_page_token:
            break
    
    return videos

def get_video_stats(video_id):
    """
    Get statistics (like count, view count, comment count) for a given video.
    """
    try:
        request = youtube.videos().list(
            part="statistics",
            id=video_id
        )
        response = request.execute()
        stats = response["items"][0]["statistics"]
        video_stats = {
            "view_count": int(stats.get("viewCount", 0)),
            "like_count": int(stats.get("likeCount", 0)),
            "comment_count": int(stats.get("commentCount", 0))
        }
        return video_stats
    except HttpError as e:
        print(f"An HTTP error occurred: {e}")
        return {}

def get_comments(video_id, max_results=100):
    """
    Get comments for a given video ID. Default max_results is set to 100 (maximum allowed).
    This function also handles pagination to retrieve all comments for a video.
    """
    comments = []
    next_page_token = None

    while True:
        try:
            # Get comments for a given video ID
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id,
                maxResults=max_results,  # Set maxResults to the maximum (100)
                textFormat="plainText",
                pageToken=next_page_token  # Handle pagination with nextPageToken
            )
            response = request.execute()
            
            for item in response.get("items", []):
                comment_data = item["snippet"]["topLevelComment"]["snippet"]

                # Capture top-level comment information
                comment = {
                    "text": comment_data["textDisplay"],
                    "like_count": comment_data.get("likeCount", 0),
                    "author": comment_data["authorDisplayName"],
                    "published_at": comment_data["publishedAt"],
                    "replies": []  # Initialize an empty list for replies
                }
                
                # Check if there are replies
                if "replies" in item:
                    for reply in item["replies"]["comments"]:
                        reply_data = reply["snippet"]
                        comment["replies"].append({
                            "text": reply_data["textDisplay"],
                            "author": reply_data["authorDisplayName"],
                            "published_at": reply_data["publishedAt"],
                            "like_count": reply_data.get("likeCount", 0)
                        })
                
                comments.append(comment)
            
            # Check if there is another page of comments
            next_page_token = response.get("nextPageToken")
            if not next_page_token:
                break

        except HttpError as e:
            error_code = e.resp.status
            if error_code == 403:
                # Handle case where comments are disabled
                error_reason = json.loads(e.content).get("error", {}).get("errors", [{}])[0].get("reason", "")
                if error_reason == "commentsDisabled":
                    print(f"Comments are disabled for video ID: {video_id}")
                else:
                    print(f"An HTTP 403 error occurred: {e}")
            elif error_code == 400:
                # Handle case where the request is malformed
                print(f"An HTTP 400 error occurred. Possible reasons could be an invalid video ID or incorrect parameters. Error details: {e}")
            else:
                # Handle other HTTP errors
                print(f"An HTTP error occurred: {e}")
            break

    return comments


# Function to get hashtags from video description
def extract_hashtags(description):
    hashtags = [word for word in description.split() if word.startswith('#')]
    return hashtags

# %%
import json

# Initialize an empty list to store results
data = []
# Set a limit for the total number of records to be collected per hashtag
HASHTAG_LIMIT = 250

# Define your list of hashtags

hashtags = ["#paris2024", "#tokyo2020", "#rio2016"]
# Iterate through each hashtag to collect video data
for hashtag in hashtags:
    hashtag_data = []  # List to store data for each individual hashtag
    print(f"Collecting data for hashtag: {hashtag}")

    # Retrieve video details using the hashtag with a maximum of 50 results per request and handle pagination
    video_details = get_video_details_by_hashtag(hashtag, max_results=50)
    
    for video in video_details:
        # Check if the number of records for this hashtag has reached the limit
        if len(hashtag_data) >= HASHTAG_LIMIT:
            break  # Exit the loop when the limit is reached for this hashtag

        # Get video statistics (like count, view count, comment count)
        video_stats = get_video_stats(video["video_id"])
        
        # Get comments, replies, and likes for comments with a maximum of 100 results per request and handle pagination
        comments = get_comments(video["video_id"], max_results=100)
        
        # Extract hashtags from the description
        extracted_hashtags = extract_hashtags(video["description"])
        
        # Combine all information into one data structure and add it to the hashtag-specific list
        hashtag_data.append({
            "Hashtag": hashtag,
            "Video Title": video["title"],
            "Video Tuthor": video["author"],
            "Description": video["description"],
            "Extracted Hashtags": extracted_hashtags,
            "View Count": video_stats.get("view_count", 0),
            "Like Count": video_stats.get("like_count", 0),
            "Comment Count": video_stats.get("comment_count", 0),
            "Comments": comments,
            "Publish Time": video["publish_time"]
        })

    # Add the data collected for the hashtag to the main data list
    data.extend(hashtag_data)
    print(f"Total records collected for hashtag '{hashtag}': {len(hashtag_data)}")

# Print the total number of records collected for all hashtags
print(f"Total records collected for all hashtags: {len(data)}")

# Save data to a JSON file
with open("youtube_olympics_data_limited_1000_per_hashtag.json", "w") as json_file:
    json.dump(data, json_file, indent=4)
# Out:
# Collecting data for hashtag: #paris2024
# Comments are disabled for video ID: TSkbzGvCyEc
# Comments are disabled for video ID: xAooUNe_tBw
# Comments are disabled for video ID: hbPY28j-zT4
# Total records collected for hashtag '#paris2024': 250
# Collecting data for hashtag: #tokyo2020
# Comments are disabled for video ID: 0Wmwc8u98lI
# Comments are disabled for video ID: ixE1a6_l7e4
# Comments are disabled for video ID: bzdxwj4422Q
# Comments are disabled for video ID: LqeB__O5B7k
# Comments are disabled for video ID: MmdtZMi4mQ0
# Comments are disabled for video ID: TM4CYbTNzGc
# Comments are disabled for video ID: ZCxiPW-QMRY
# Comments are disabled for video ID: QJG6duYxpMY
# Comments are disabled for video ID: QJG6duYxpMY
# Comments are disabled for video ID: n0RxOm0dhGg
# Comments are disabled for video ID: _e_dnSMEPQw
# Comments are disabled for video ID: GfIzR4RXFag
# Comments are disabled for video ID: Y31qV7mK1L4
# Comments are disabled for video ID: pCK2pRbwnUk
# Comments are disabled for video ID: c-zzmf-1NE0
# Comments are disabled for video ID: MmdtZMi4mQ0
# Comments are disabled for video ID: 4t_7P9LShqU
# Comments are disabled for video ID: W5Vbqq3UQDo
# Comments are disabled for video ID: ZCxiPW-QMRY
# Total records collected for hashtag '#tokyo2020': 250
# Collecting data for hashtag: #rio2016
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=MynDVCpPRbo&maxResults=100&textFormat=plainText&pageToken=Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJZ2dHQUFTQlFpSElCZ0FFZ1VJcUNBWUFCSUZDSWtnR0FBU0JRaWRJQmdCR0FBaURnb01DS3YyM2ZjRkVMakl4ODhC&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=xG91krXuxyw&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=xG91krXuxyw&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=_8EEfsHqp74&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=_8EEfsHqp74&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=rGyd8YmulWk&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=rGyd8YmulWk&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=5xRpTK9CUKk&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=5xRpTK9CUKk&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=fhkPTebxGUw&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=fhkPTebxGUw&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=1Nrn1Zrn9SQ&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=1Nrn1Zrn9SQ&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=fLU45AslIuk&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=fLU45AslIuk&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=CFEG3Mq1cDg&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=CFEG3Mq1cDg&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=MaxT2vguGXQ&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=MaxT2vguGXQ&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=uTVNr5mmaq8&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=uTVNr5mmaq8&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=fXIbLmlUdOQ&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=fXIbLmlUdOQ&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=zW87tVnDKIU&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=zW87tVnDKIU&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=Hf-n1yfd8II&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=Hf-n1yfd8II&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=YyH0-WFshtM&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=YyH0-WFshtM&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=zgEeYfAcavI&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=zgEeYfAcavI&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=9WUQL03eNTM&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=9WUQL03eNTM&maxResults=100&textFormat=plainText&pageToken=Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNLZ2dHQUFTQlFpZElCZ0JFZ1VJaVNBWUFCSUZDSWdnR0FBU0JRaUhJQmdBR0FBaURnb01DUDdUd2F3R0VPanhxdndC&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=v-n_MRIfDFw&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=v-n_MRIfDFw&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=v-n_MRIfDFw&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=v-n_MRIfDFw&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=k4ux0jau_ws&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=k4ux0jau_ws&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=ObSDD2vfGMA&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=ObSDD2vfGMA&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=u7uClp4FybA&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=u7uClp4FybA&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=YyH0-WFshtM&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=5xRpTK9CUKk&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=5xRpTK9CUKk&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=1Nrn1Zrn9SQ&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=1Nrn1Zrn9SQ&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=_FFIGnqisJo&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=_FFIGnqisJo&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=n_70iW75YG8&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=n_70iW75YG8&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=-S3g7EmDGoQ&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=-S3g7EmDGoQ&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=MgPM0iQCnWo&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=MgPM0iQCnWo&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=GnmOSYH-tog&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=GnmOSYH-tog&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=I4T9TiVC-Y0&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=I4T9TiVC-Y0&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=7TnMwVyQATY&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=7TnMwVyQATY&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=0J9lNzvvn30&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=0J9lNzvvn30&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=Ngcyn9coRO8&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=Ngcyn9coRO8&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=8ihOhduFDPo&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=8ihOhduFDPo&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=9WUQL03eNTM&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=9WUQL03eNTM&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=qyOpdQO2__c&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=qyOpdQO2__c&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=m1zmvJbFlIY&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=m1zmvJbFlIY&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=1e_PxoDM614&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=1e_PxoDM614&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=W1EesPbkaW4&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=W1EesPbkaW4&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=6k-R8Jq5nh8&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=6k-R8Jq5nh8&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=IocLkk3aYlk&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=IocLkk3aYlk&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=8dyug7s9EPw&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=8dyug7s9EPw&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# ...
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=rZoZs6aSdps&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=Sj40gwWSH1w&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=Sj40gwWSH1w&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=e6oX9pT1WrE&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=e6oX9pT1WrE&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=Pu9mnVV6_fA&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=Pu9mnVV6_fA&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=-OhTtyA6PEg&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=-OhTtyA6PEg&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=cPG8czeJVXM&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=cPG8czeJVXM&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=1uKpiedsubo&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=1uKpiedsubo&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=m6rKKZAWF5Q&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=m6rKKZAWF5Q&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=EixISM6Dgi8&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=EixISM6Dgi8&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=vlGlTn1g6M8&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=bbJwuaOo_3Q&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=bbJwuaOo_3Q&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=1OmSm1S1z60&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=1OmSm1S1z60&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=Fgq_AEUOqBM&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=Fgq_AEUOqBM&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=jPwDWMfy7Z4&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=jPwDWMfy7Z4&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=eg5gIW3ijW8&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# An HTTP 403 error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=eg5gIW3ijW8&maxResults=100&textFormat=plainText&key=AIzaSyDgT6rFB2QXbfllRk-MVAZAMYAFz4DmorM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Total records collected for hashtag '#rio2016': 250
# Total records collected for all hashtags: 750

# %%
len(data)
# Out:
# 750
